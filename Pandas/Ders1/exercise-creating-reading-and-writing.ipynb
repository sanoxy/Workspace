# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/creating-reading-and-writing).**
#
# ---

# %% [markdown]
# # Introduction
#
# The first step in most data analytics projects is reading the data file. In this exercise, you'll create Series and DataFrame objects, both by hand and by reading data files.
#
# Run the code cell below to load libraries you will need (including code to check your answers).

# %%
import pandas as pd
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://i.imgur.com/Ax3pp2A.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
fruits = pd.DataFrame({"Apples":[30],"Bananas":[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruits = pd.DataFrame([[30,21]],columns=['Apples','Bananas'])
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://i.imgur.com/CHPn7ZF.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
fruits = pd.DataFrame([[35,21],[41,34]],columns=["Apples","Bananas"],index=["2017 Sales","2018 Sales"])
fruits
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingredients = pd.Series(["4 cups","1 cup","2 large","1 can"],index=["Flour","Milk","Eggs","Spam"],name="Dinner")
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://i.imgur.com/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
reviews = pd.read_csv("/content/sample_data/winemag-data-130k-v2.csv", index_col = 0)
reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 12944    France  The Côte du Py, one of the best cru vineyard s...
# 12945    France  Be grateful that Stéphane Aviron is an old-vin...
# 12946        US  As the Stolpman family's top-of-the-line bottl...
# 12947        US  Hailing from a precipitously perched vineyard ...
# 12948   Austria  The tanginess of grapefruit peel, paired with ...
#
#                               designation  points  price           province  \
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# ...                                   ...     ...    ...                ...
# 12944          Côte du Py Vieilles Vignes      94   24.0         Beaujolais
# 12945                     Vieilles Vignes      94   24.0         Beaujolais
# 12946                              Angeli      94   68.0         California
# 12947                  Diamond T Vineyard      94   52.0         California
# 12948                  Loibenberg Smaragd      94   39.0             Wachau
#
#                   region_1           region_2         taster_name  \
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
# ...                    ...                ...                 ...
# 12944               Morgon                NaN          Roger Voss
# 12945        Moulin-à-Vent                NaN          Roger Voss
# 12946       Ballard Canyon      Central Coast       Matt Kettmann
# 12947             Monterey      Central Coast       Matt Kettmann
# 12948                  NaN                NaN           Anne Kreb
#
#       taster_twitter_handle  \
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
# ...                     ...
# 12944            @vossroger
# 12945            @vossroger
# 12946         @mattkettmann
# 12947         @mattkettmann
# 12948                   NaN
#
#                                                    title         variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                  ...             ...
# 12944  Stéphane Aviron 2014 Côte du Py Vieilles Vigne...           Gamay
# 12945  Stéphane Aviron 2014 Vieilles Vignes  (Moulin-...           Gamay
# 12946        Stolpman 2014 Angeli Syrah (Ballard Canyon)           Syrah
# 12947  Talbott 2014 Diamond T Vineyard Pinot Noir (Mo...      Pinot Noir
# 12948                                                NaN             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# 2                Rainstorm
# 3               St. Julian
# 4             Sweet Cheeks
# ...                    ...
# 12944      Stéphane Aviron
# 12945      Stéphane Aviron
# 12946             Stolpman
# 12947              Talbott
# 12948                  NaN
#
# [12949 rows x 13 columns]

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
# Your code goes here

animals.to_csv("cows_and_goats.csv")

# %% [markdown]
# # Keep going
#
# Move on to learn about **[indexing, selecting and assigning](https://www.kaggle.com/residentmario/indexing-selecting-assigning)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
